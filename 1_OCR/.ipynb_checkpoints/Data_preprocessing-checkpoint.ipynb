# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
dataset = os.getcwd()+'/Data Files/Dataset/'
dataset
# Out:
# '/home/sharan/Desktop/Personal Projects/LoveIsLove/1_OCR/Data Files/Dataset/'

# %%
img = cv2.imread(dataset+'Test108.jpg',0)

# %%
''''Adaptive Thresholding: This method gives a threshold 
for a small part of the image depending on the characteristics
of its locality and neighbours i.e there is no single fixed 
threshold for the whole image but every small part of the
image has a different threshold depending upon the locality
and also gives smooth transition.'''

adaptive_threshold_img = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2) #imgf contains Binary image

# %%
plt.imshow(adaptive_threshold_img)
plt.show()

# %%
#Denoising

adaptive_threshold_img = cv2.cvtColor(adaptive_threshold_img, cv2.COLOR_GRAY2BGR) 
denoised_img = cv2.fastNlMeansDenoisingColored(adaptive_threshold_img, None, 10, 10, 7, 15) 
 
plt.imshow(denoised_img) 
plt.show()
cv2.imwrite('test.jpg',denoised_img)
# Out:
# True

# %%
def preprocess(filename):
    img = cv2.imread(dataset+filename,0)
    adaptive_threshold_img = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
    adaptive_threshold_img = cv2.cvtColor(adaptive_threshold_img, cv2.COLOR_GRAY2BGR) 
    denoised_img = cv2.fastNlMeansDenoisingColored(adaptive_threshold_img, None, 10, 10, 7, 15) 
    cv2.imwrite(os.getcwd()+'/preprocessed_data/'+filename,denoised_image)

# %%
for file in os.listdir(dataset):
    preprocess(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-6f13ed9e7cd2> in <module>
#       1 for file in os.listdir(dataset):
# ----> 2     preprocess(file)
#
# <ipython-input-96-fbb298a2e56d> in preprocess(filename)
#       4     adaptive_threshold_img = cv2.cvtColor(adaptive_threshold_img, cv2.COLOR_GRAY2BGR)
#       5     denoised_img = cv2.fastNlMeansDenoisingColored(adaptive_threshold_img, None, 10, 10, 7, 15)
# ----> 6     cv2.imwrite('preprocessed_data/'+filename,denoised_image)
#
# NameError: name 'denoised_image' is not defined
